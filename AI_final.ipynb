# %%
from attention import AttentionLayer

# %%
import numpy as np
import pandas as pd 
import re
from bs4 import BeautifulSoup
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
data=pd.read_csv("Reviews.csv",nrows=100000)

# %%
data.drop_duplicates(subset=['Text'],inplace=True)#dropping duplicates
data.dropna(axis=0,inplace=True)#dropping na

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88421 entries, 0 to 99999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Id                      88421 non-null  int64
#  1   ProductId               88421 non-null  object
#  2   UserId                  88421 non-null  object
#  3   ProfileName             88421 non-null  object
#  4   HelpfulnessNumerator    88421 non-null  int64
#  5   HelpfulnessDenominator  88421 non-null  int64
#  6   Score                   88421 non-null  int64
#  7   Time                    88421 non-null  int64
#  8   Summary                 88421 non-null  object
#  9   Text                    88421 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 7.4+ MB

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
stop_words = set(stopwords.words('english')) 

def text_cleaner(text,num):
    newString = text.lower()
#     newString = BeautifulSoup(newString, "lxml").text
    newString = re.sub(r'\([^)]*\)', '', newString)
    newString = re.sub('"','', newString)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString) 
    newString = re.sub('[m]{2,}', 'mm', newString)
    if(num==0):
        tokens = [w for w in newString.split() if not w in stop_words]
    else:
        tokens=newString.split()
    long_words=[]
    for i in tokens:
        if len(i)>1:                                                 #removing short word
            long_words.append(i)   
    return (" ".join(long_words)).strip()

# %%
cleaned_text = []
for t in data['Text']:
    cleaned_text.append(text_cleaner(t,0))

# %%
cleaned_text[:5]
# Out:
# ['bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better',
#  'product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo',
#  'confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch',
#  'looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal',
#  'great taffy great price wide assortment yummy taffy delivery quick taffy lover deal']

# %%
cleaned_summary = []
for t in data['Summary']:
    cleaned_summary.append(text_cleaner(t,1))

cleaned_summary[:10]
# Out:
# ['good quality dog food',
#  'not as advertised',
#  'delight says it all',
#  'cough medicine',
#  'great taffy',
#  'nice taffy',
#  'great just as good as the expensive brands',
#  'wonderful tasty taffy',
#  'yay barley',
#  'healthy dog food']

# %%
data['cleaned_text']=cleaned_text
data['cleaned_summary']=cleaned_summary

# %%
data.replace('', np.nan, inplace=True)
data.dropna(axis=0,inplace=True)

# %%
import matplotlib.pyplot as plt

text_word_count = []
summary_word_count = []

# populate the lists with sentence lengths
for i in data['cleaned_text']:
      text_word_count.append(len(i.split()))

for i in data['cleaned_summary']:
      summary_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text':text_word_count, 'summary':summary_word_count})

length_df.hist(bins = 30)
plt.show()

# %%
cnt=0
for i in data['cleaned_summary']:
    if(len(i.split())<=8):
        cnt=cnt+1
print(cnt/len(data['cleaned_summary']))
# Out:
# 0.942445473169517

# %%
max_text_len=30
max_summary_len=8
cleaned_text =np.array(data['cleaned_text'])
cleaned_summary=np.array(data['cleaned_summary'])

short_text=[]
short_summary=[]

for i in range(len(cleaned_text)):
    if(len(cleaned_summary[i].split())<=max_summary_len and len(cleaned_text[i].split())<=max_text_len):
        short_text.append(cleaned_text[i])
        short_summary.append(cleaned_summary[i])
        
df=pd.DataFrame({'text':short_text,'summary':short_summary})

# %%
df['summary'] = df['summary'].apply(lambda x : 'sostok '+ x + ' eostok')

# %%
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(np.array(df['text']),np.array(df['summary']),test_size=0.1,random_state=0,shuffle=True)

# %%
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences

#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer() 
x_tokenizer.fit_on_texts(list(x_tr))

# %%
thresh=4
cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in x_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 64.63591405184175
# Total Coverage of rare words: 2.8138216800058062

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr_seq    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val_seq   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr_seq,  maxlen=max_text_len, padding='post')
x_val   =   pad_sequences(x_val_seq, maxlen=max_text_len, padding='post')

#size of vocabulary ( +1 for padding token)
x_voc   =  x_tokenizer.num_words + 1

# %%
x_voc
# Out:
# 8296

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer()   
y_tokenizer.fit_on_texts(list(y_tr))

# %%
thresh=6
cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in y_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 78.4020390070922
# Total Coverage of rare words: 5.4749803727118715

# %%
y_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
y_tokenizer.fit_on_texts(list(y_tr))

#convert text sequences into integer sequences
y_tr_seq    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val_seq   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr_seq, maxlen=max_summary_len, padding='post')
y_val   =   pad_sequences(y_val_seq, maxlen=max_summary_len, padding='post')

#size of vocabulary
y_voc  =   y_tokenizer.num_words +1
y_tokenizer.word_counts['sostok'],len(y_tr)
# Out:
# (41655, 41655)

# %%
ind=[]
for i in range(len(y_tr)):
    cnt=0
    for j in y_tr[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_tr=np.delete(y_tr,ind, axis=0)
x_tr=np.delete(x_tr,ind, axis=0)

# %%
ind=[]
for i in range(len(y_val)):
    cnt=0
    for j in y_val[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_val=np.delete(y_val,ind, axis=0)
x_val=np.delete(x_val,ind, axis=0)

# %%
from keras import backend as K 
K.clear_session()

latent_dim = 300
embedding_dim=100

# Encoder
encoder_inputs = Input(shape=(max_text_len,))

#embedding layer
enc_emb =  Embedding(x_voc, embedding_dim,trainable=True)(encoder_inputs)

#encoder lstm 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

#encoder lstm 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

#encoder lstm 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))

#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True,dropout=0.4,recurrent_dropout=0.2)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])

# Attention layer
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# Concat attention input and decoder LSTM output
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

#dense layer
decoder_dense =  TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_concat_input)

# Define the model 
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 30)           0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 30, 100)      829600      input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 30, 300), (N 481200      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 30, 300), (N 721200      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 100)    195000      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 30, 300), (N 721200      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 300),  481200      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer [(None, None, 300),  180300      lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 600)    0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 1950)   1171950     concat_layer[0][0]
# ==================================================================================================
# Total params: 4,781,650
# Trainable params: 4,781,650
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# %%
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=50,batch_size=128, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# Out:
# Train on 40556 samples, validate on 4500 samples
# Epoch 1/50
# 40556/40556 [==============================] - 140s 3ms/step - loss: 2.8076 - val_loss: 2.5608
# Epoch 2/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 2.5041 - val_loss: 2.4176
# Epoch 3/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 2.3575 - val_loss: 2.2846
# Epoch 4/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 2.2497 - val_loss: 2.2170
# Epoch 5/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 2.1795 - val_loss: 2.1684
# Epoch 6/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 2.1281 - val_loss: 2.1442
# Epoch 7/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 2.0855 - val_loss: 2.1141
# Epoch 8/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 2.0486 - val_loss: 2.0993
# Epoch 9/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 2.0143 - val_loss: 2.0813
# Epoch 10/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.9833 - val_loss: 2.0630
# Epoch 11/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.9560 - val_loss: 2.0538
# Epoch 12/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.9308 - val_loss: 2.0480
# Epoch 13/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.9050 - val_loss: 2.0400
# Epoch 14/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.8831 - val_loss: 2.0310
# Epoch 15/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.8619 - val_loss: 2.0313
# Epoch 16/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.8413 - val_loss: 2.0231
# Epoch 17/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.8220 - val_loss: 2.0233
# Epoch 18/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.8028 - val_loss: 2.0218
# Epoch 19/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.7866 - val_loss: 2.0241
# Epoch 20/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.7710 - val_loss: 2.0190
# Epoch 21/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.7537 - val_loss: 2.0272
# Epoch 22/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.7390 - val_loss: 2.0257
# Epoch 23/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.7225 - val_loss: 2.0265
# Epoch 24/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.7070 - val_loss: 2.0314
# Epoch 25/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.6942 - val_loss: 2.0232
# Epoch 26/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.6821 - val_loss: 2.0275
# Epoch 27/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.6676 - val_loss: 2.0249
# Epoch 28/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.6576 - val_loss: 2.0319
# Epoch 29/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.6439 - val_loss: 2.0347
# Epoch 30/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.6300 - val_loss: 2.0419
# Epoch 31/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.6189 - val_loss: 2.0446
# Epoch 32/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.6095 - val_loss: 2.0450
# Epoch 33/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.5994 - val_loss: 2.0481
# Epoch 34/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.5873 - val_loss: 2.0493
# Epoch 35/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.5776 - val_loss: 2.0563
# Epoch 36/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.5671 - val_loss: 2.0655
# Epoch 37/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.5591 - val_loss: 2.0605
# Epoch 38/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.5487 - val_loss: 2.0718
# Epoch 39/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.5400 - val_loss: 2.0789
# Epoch 40/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.5302 - val_loss: 2.0713
# Epoch 41/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.5209 - val_loss: 2.0807
# Epoch 42/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.5121 - val_loss: 2.0898
# Epoch 43/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.5047 - val_loss: 2.0815
# Epoch 44/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.4974 - val_loss: 2.0866
# Epoch 45/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.4882 - val_loss: 2.0895
# Epoch 46/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.4818 - val_loss: 2.1004
# Epoch 47/50
# 40556/40556 [==============================] - 128s 3ms/step - loss: 1.4744 - val_loss: 2.1083
# Epoch 48/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.4679 - val_loss: 2.0973
# Epoch 49/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.4611 - val_loss: 2.1071
# Epoch 50/50
# 40556/40556 [==============================] - 127s 3ms/step - loss: 1.4521 - val_loss: 2.1066

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
reverse_target_word_index=y_tokenizer.index_word
reverse_source_word_index=x_tokenizer.index_word
target_word_index=y_tokenizer.word_index

# %%
# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_text_len,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs) 
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat) 

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)
    
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
      
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        
        if(sampled_token!='eostok'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eostok'  or len(decoded_sentence.split()) >= (max_summary_len-1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sostok']) and i!=target_word_index['eostok']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
for i in range(0,100):
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_len)))
    print("\n")
# Out:
# Review: lazy often eat frozen lunches work healthy choice fresh mixers easy make taste way better frozen lunches br br enjoyed every flavor far including one
# Original summary: way better than frozen
# Predicted summary:  my baby loves it
#
#
# Review: crunch product really fills bill combination slight dark chocolate taste amazing caramel taste great plus calories pouch cannot beat
# Original summary: great snack
# Predicted summary:  delicious
#
#
# Review: finally gluten free chip tastes great light flavorful certainly ordering soon
# Original summary: great taste gluten free
# Predicted summary:  gluten free
#
#
# Review: two aunt cookies contain daily fat cookies full grease fall apart may sugar free gluten free make mostly fat cannot even give grandchildren
# Original summary: cookies
# Predicted summary:  cookies
#
#
# Review: one best gluten free mix market makes fluffy pancakes light cornbread also great price different mixes market price best
# Original summary: wonderful
# Predicted summary:  great gluten free pasta
#
#
# Review: diabetic one treat gets rid craving something else love smaller cans perfect fresh tasty packed care delivered usual time love
# Original summary: my secret treat
# Predicted summary:  great treat
#
#
# Review: used buy grocery store looks like going online best taco sauce even la victoria red mild compare
# Original summary: great sauce
# Predicted summary:  sauce
#
#
# Review: catnip fine packaging changed zip lock bag bag contains ounces catnip rather ounces noted item description cats liked enough still economical way purchase catnip bag last quite cat
# Original summary: description needs
# Predicted summary:  old
#
#
# Review: ordered item tuesday received thursday made absolutely wonderful taste like kind thai restaurants searching tea glad found buying thank
# Original summary: finally found it
# Predicted summary:  great tea
#
#
# Review: generally sheds incredible amount especially spring started shed stop weeks ago amazing much difference seeing shedding really diminished coat looks great
# Original summary: amazing product to
# Predicted summary:  best ever
#
#
# Review: expecting stronger flavour still delicious want stronger set cup size smaller flavour intense
# Original summary: coffee
# Predicted summary:  good coffee
#
#
# Review: use goat milk everything use replace cow milk recipes coffee works well price great highly recommend
# Original summary: love goat milk
# Predicted summary:  great product
#
#
# Review: received shipment tasty chips title says mg sodium almost double amount listed amazon product page
# Original summary: sodium not as by amazon
# Predicted summary:  kettle chips
#
#
# Review: watch tea bulbs open bloom nice fragrance delicate taste one bulb makes pot cups br exciting brewed clear glass teapot candle underneath light tea night mm calming
# Original summary: love this tasting tea
# Predicted summary:  love this tea
#
#
# Review: received sample quaker soft baked cereal bar complimentary testing purposes influenster warmed microwave work delicious quick simple snack tasty healthier hold till next meal buying box next time grocery store
# Original summary: delicious
# Predicted summary:  delicious
#
#
# Review: family loves sometimes difficult find also quick easy
# Original summary: these are awesome
# Predicted summary:  great
#
#
# Review: love product really taste awesome toast thrilled natural brought school teachers try lunch teachers room huge hit
# Original summary: my opinion
# Predicted summary:  my dog loves this
#
#
# Review: oh goodness delicious snack bar definitely going staple pantry soft flavorful satisfied snack craving would perfect quick energy boost work meal go morning definitely purchasing item
# Original summary: so yummy
# Predicted summary:  delicious
#
#
# Review: one perfect box rips tears inside box badly dented cans chowder looked like fell airplane every single disappointed return chowder good joke rate star box
# Original summary: from
# Predicted summary:  great product
#
#
# Review: great fast cook pasta packaging packaging quite weird came shipping box large plastic bag without description hope got bought
# Original summary: great pasta
# Predicted summary:  pasta
#
#
# Review: dogs love treats three dogs ate wanted healthy treat dogs would recommend
# Original summary: dogs love them
# Predicted summary:  dogs love them
#
#
# Review: love salt holy crap mix salty make bloody mary add salt even finished drink mouth feels like ate entire bag sunflower seeds almost undrinkable opinion
# Original summary: way too salty
# Predicted summary:  too salty
#
#
# Review: tasty snack food would definitely purchase healthy snack
# Original summary: american gourmet smart puffs
# Predicted summary:  great snack
#
#
# Review: true flavor last long time tastes great lasts long enough
# Original summary: great taste
# Predicted summary:  love this stuff
#
#
# Review: tasted many different kinds coconut water exceeds preserves natural taste coconut without bitter sweet healthy delicious refreshing glad discovered
# Original summary: yes this is it
# Predicted summary:  best coconut water
#
#
# Review: common ingredient products gelatin consists animal products bones skin hair etc stewed hours surface sludge voila gelatin br br company needs remove vegetarian products use gelatin
# Original summary: this product is not vegetarian
# Predicted summary:  not for me
#
#
# Review: fiance new york great whole thing sent thank gift got enthusiastic thank letter loved basket would get
# Original summary: was
# Predicted summary:  gift
#
#
# Review: great tasting tea plenty anti oxidants easy make easy store even kids like good value well
# Original summary: love this
# Predicted summary:  great tea
#
#
# Review: get fresh bold thick flavor coffee never bitter addicted blend decaf night sleep great price
# Original summary: this is the best coffee
# Predicted summary:  best coffee
#
#
# Review: thank much love yeast makes beer smooth nice made alot people happy
# Original summary: perfect
# Predicted summary:  great
#
#
# Review: tastes great used supplement cooking also people given concerns packaging mine completely fine
# Original summary: tastes great
# Predicted summary:  great product
#
#
# Review: actually buy tried adding individual oz bottles cart check found shipping ouch beware
# Original summary: outrageous shipping
# Predicted summary:  damaged cans
#
#
# Review: love pop chips ceased available area happy find available amazon free shipping yummy also healthy choice cannot beat deal like
# Original summary: great snack
# Predicted summary:  pop chips
#
#
# Review: firm believer nescafe best available instant decided try like coffee strong need lot stuff classic bad nescafe better
# Original summary: stick to
# Predicted summary:  good but not great
#
#
# Review: terrible product drawer open close without making space saver hard eyes would return refund terribly lazy go bed bath beyond use coupon something else worth
# Original summary: for us better off with different product
# Predicted summary:  not so good
#
#
# Review: tea tastes great longer find local store believe decaf drink night keep cares says package price keeps wish would settle box instead enjoy
# Original summary: great tasting tea
# Predicted summary:  great tea
#
#
# Review: enjoy martini product waste olives purchase juice try product sure agree
# Original summary: olive juice
# Predicted summary:  not that great
#
#
# Review: well like black licorice like damn br br like good plenty much better softer stick teeth bad thing like cannot put
# Original summary: these are awesome
# Predicted summary:  good but not the best
#
#
# Review: rainforest mild coffee good time day coffee san francisco bay excellent opinion cup design plastic cups others never failure grind coffee cup using product disapointed product
# Original summary: best coffee for brewers
# Predicted summary:  great coffee
#
#
# Review: picky month old eat anything brand oatmeal loves really make happy baby
# Original summary: only cereal my son will eat
# Predicted summary:  my son loves it
#
#
# Review: one thing dog likes liver biscotti dog treats make best rewards training treats used
# Original summary: make your dog happy
# Predicted summary:  great for training
#
#
# Review: cannot find live turned amazon purchase arrived quickly fresh made happy thought look online definitely order
# Original summary: exactly as remembered them love swedish fish
# Predicted summary:  great
#
#
# Review: always loved still years got ice gift recently really enjoying good stuff
# Original summary: ice yummy
# Predicted summary:  great gift
#
#
# Review: buy chicken cat learned speak english order get treats economical obviously well liked cat
# Original summary: my cat for these treats
# Predicted summary:  my cat loves these
#
#
# Review: absolutly delicious ordered several times always fresh tasty freeze mine cuz like word lol nuts drive nuts eat great snack healthy eat
# Original summary: am nutty over these
# Predicted summary:  delicious
#
#
# Review: great taste well fill keep healthy helps fill food cravings add pounds
# Original summary: nature valley granola bars
# Predicted summary:  great snack
#
#
# Review: time lived england became aware product pleasantly surprised found amazon continue purchase consume fresh light refreshing drink needed hard day office
# Original summary: refreshingly good
# Predicted summary:  love it
#
#
# Review: dogs love treats say dont blame smell soo good feel good giving babies healthy treats made us china another good flavor pumpkin apple
# Original summary: my dogs love it
# Predicted summary:  dogs love them
#
#
# Review: bought two sending back inches look big ad lids keep popping waste money buying pieces junk
# Original summary: smaller than it looks
# Predicted summary:  not the same as the original
#
#
# Review: gummy bears simply amazing thing would say con bag resealable nothing simple plastic container fix big deal
# Original summary: so many gummy bears so little time
# Predicted summary:  best gummi bears
#
#
# Review: stuff ok easy make scratch waste money google horchata million recipes
# Original summary: make your own
# Predicted summary:  not the best
#
#
# Review: use flour breads base add expensive flours change flavors want works wonderful highly nutritious mild flavor blends well flours since somewhat difficult find love buying bulk
# Original summary: great flour for
# Predicted summary:  great flour for gluten free baking
#
#
# Review: excited able find candy looking ages received quickly candy well packaged fresh flavor buy thank
# Original summary: great product service
# Predicted summary:  great candy
#
#
# Review: ball exactly minutes tore rubber disappointed concept exactly needs
# Original summary: not happy
# Predicted summary:  not what expected
#
#
# Review: fog chaser great ordered twice continue order comes nicely boxed packaged bought count box price best found cents cup
# Original summary: loved
# Predicted summary:  great deal
#
#
# Review: exact product available sams club wow prime membership really paying product
# Original summary: what rip off
# Predicted summary:  not what expected
#
#
# Review: happy machine works great work saves money bottom
# Original summary: first
# Predicted summary:  great coffee
#
#
# Review: hard grow grew cat loved found seeds work well yet still looking would buy better luck growing
# Original summary: good for kitty
# Predicted summary:  cat loves it
#
#
# Review: love add coconut milk water make
# Original summary: yum yum
# Predicted summary:  great taste
#
#
# Review: kashi bars okay know would buy especially quantity chocolate bottom nice whole grain healthy tasting
# Original summary: kashi bars
# Predicted summary:  good but not great
#
#
# Review: love flavor tea hard time finding stores glad amazon wife loves flavor drinks flavors brands product delivered promised
# Original summary: davidson tea cherry with almond
# Predicted summary:  great tea
#
#
# Review: used problems digestion lot gas since started taking type honey every meal things got lot better love
# Original summary: simply amazing
# Predicted summary:  amazing
#
#
# Review: matcha tea exactly expected extremely green great flavor keep mind way matcha expert limited experience type tea great got product within days ordering far estimated date delivery highly recommend seller
# Original summary: great product quick service
# Predicted summary:  tea
#
#
# Review: like flavored butter questionable taste definitely worth money br expected much
# Original summary: not worth the money
# Predicted summary:  not bad
#
#
# Review: tuna strong fishy taste also disapointed mg sodium says salt added
# Original summary: did not like this stuff
# Predicted summary:  too salty
#
#
# Review: leash gives poop bag needed success fits common refill bags find major stores
# Original summary: it does two things
# Predicted summary:  great product
#
#
# Review: ordered product dog loves one cares degrees outside recieved one big melted ball thought would ship dry ice summer hot area dont order
# Original summary: dont do it
# Predicted summary:  my dog loves them
#
#
# Review: buy happy hips treats year old husky loves great need pill easy medication dose best treats contain glucosamine chondroitin movement improves time
# Original summary: happy hips for happy dog
# Predicted summary:  my dog loves these
#
#
# Review: great buy great product saves money even leave house buy product amazon
# Original summary: great buy
# Predicted summary:  great buy
#
#
# Review: tazo refresh great selection caffeine free tea love mint taste tea needs sweetner added tasty hot cold
# Original summary: refreshing and
# Predicted summary:  tea
#
#
# Review: wife love travel bicycle summer time winter time car year around snacks really good situations fan peanut bar tried peanut almond become favorite highly recommended
# Original summary: great snack for travel time
# Predicted summary:  great snack
#
#
# Review: stuff amazing tastes exactly like sugar looks like sugar substitute sugar husband detected sugar bowl five months still thinks sugar
# Original summary: tastes exactly like sugar no aftertaste
# Predicted summary:  sugar free
#
#
# Review: pickling spice best quality flavor results ever found years pickling cucumbers green tomatos garden vegetables experimented others cannot compare taste mccormick makes
# Original summary: best spice blend
# Predicted summary:  great for cooking
#
#
# Review: dave nuts fantastic hot spicy crunchy habit forming br br babies women wimpy men need order
# Original summary: not for
# Predicted summary:  tasty
#
#
# Review: love gummies sweet fresh natural kind wish good brand maybe brands
# Original summary: good brand
# Predicted summary:  yummy
#
#
# Review: daughter favorite first foremost love get lentils many stage vegetarian choices
# Original summary: earth best rice lentil dinner
# Predicted summary:  great
#
#
# Review: chips great calories apples taste nice tart signed repeat deliveries good funny thing boston terrier loves sound bag runs watches eat throw one every healthy treat us
# Original summary: tasty and healthy
# Predicted summary:  tasty and healthy
#
#
# Review: doggies give hard time give pill work especially give fish oil coats split pockets expensive use daily basis love flavor like cheese go figure
# Original summary: expensive
# Predicted summary:  greenies
#
#
# Review: tea best tea ever fruity caffeine free hooked great scones cookies cake
# Original summary: tea time
# Predicted summary:  great tea
#
#
# Review: huge fan canned coffee drinks always looking easy coffee drink tasted okay weird aftertaste cannot quite describe size adequate definitely purchasing future like convenient ok tasting coffee go
# Original summary: illy coffee drink
# Predicted summary:  not what expected
#
#
# Review: hooked love artisan salts use grilling every opportunity yummy
# Original summary: love it
# Predicted summary:  love this stuff
#
#
# Review: wow great product excellent quality family especially daughters love type pasta looking found amazon definetly continue purchase enjoy home thank
# Original summary: long
# Predicted summary:  great product
#
#
# Review: arent salt vinegary still flavor good tasting crispy
# Original summary: great tasting
# Predicted summary:  excellent salt
#
#
# Review: lover halvah could calories sugar free halvah almost like real thing purchase
# Original summary: great at amazon
# Predicted summary:  great product
#
#
# Review: today local farmer market bought box spot tasty sweet tooth health conscious perfect
# Original summary: pricey but amazing
# Predicted summary:  dried apples
#
#
# Review: got gift brother loves frequently pits stuffs olives loves great kitchen tool also good stuffing dates
# Original summary: does not
# Predicted summary:  great gift
#
#
# Review: affordable product works well quite accurate like enough plants reason spend money expensive moisture cheap effective product starts
# Original summary: healthy plants no more over
# Predicted summary:  product
#
#
# Review: love white mochas horrible cannot even drink came see others felt actually something wrong creamer guess alone thinking horrible calling international delight tomorrow company let something bad stores
# Original summary: horrible
# Predicted summary:  disappointed
#
#
# Review: love teacher get school meal bars get lunch keep running vending machine
# Original summary: great taste
# Predicted summary:  great bars
#
#
# Review: dog cannot get enough food three years practical travel dog really needs drink enough water dog happily drinks water needs thank amazon getting fast
# Original summary: doggie catnip
# Predicted summary:  dog loves it
#
#
# Review: flowers arrived door time expected bud form naturally gave time blossom unfortunately realized significantly less flowers vase picture advertised smell nice individual flowers pretty buying proflowers much better money delivered
# Original summary: pretty but not like the picture
# Predicted summary:  old and
#
#
# Review: used spicy foods south texas spicy doubt much habanero used could take notch two
# Original summary: not ass
# Predicted summary:  spicy
#
#
# Review: best deal kind coffee found yet local including always carry husband drink kind
# Original summary: good deal
# Predicted summary:  great coffee
#
#
# Review: good cheeze switzerland quick delivery real thing tasty
# Original summary: real
# Predicted summary:  good
#
#
# Review: great make snacks melts easy wonderful flavor ultimate american comfort cheese
# Original summary: the american comfort cheese
# Predicted summary:  delicious
#
#
# Review: justin individual nut butter packs delicious perfect back packing trips bring every time without highly recommended product
# Original summary: fantastic
# Predicted summary:  delicious
#
#
# Review: exactly ordered shipped immediately got early ordered cases husband could take one happy man sea right
# Original summary: awesome
# Predicted summary:  great service
#
#
# Review: best baking cocoa used rich deep chocolate flavor lb size economical way purchase premium cocoa
# Original summary: cooking with
# Predicted summary:  cocoa
#
#
# Review: perfect working need snack fuel yummy tastes awesome warmed
# Original summary: yummy
# Predicted summary:  delicious
#
#
# Review: cannot tell made brown rice cooks well taste well costly think best healthy option children fond pasta son loves
# Original summary: taste pretty good
# Predicted summary:  delicious
